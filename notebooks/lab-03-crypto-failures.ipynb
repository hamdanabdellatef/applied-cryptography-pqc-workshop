# %% [markdown]
# # Lab 3: Perfect Algorithm, Broken System
#
# **Scaffold only — exercises are not implemented.**
#
# Isolated vulnerable examples, diagnosis, repair, and regression checks.
#
# Use synthetic data and disposable lab keys only.

# %% [markdown]
# ## 1. Objectives and predictions
#
# TODO: State the outcomes, prerequisites, and prediction questions.

# %% [markdown]
# ## 2. Runtime setup
#
# TODO: Add pinned, repeatable installation and imports after the libraries are selected and tested in a fresh Colab CPU runtime.

# %%
import sys
print(f"Python {sys.version.split()[0]}")
print("Notebook scaffold: lab implementation pending.")

# %% [markdown]
# ## 3. Guided experiment
#
# TODO: Add short Markdown explanations followed by Python cells.

# %%
# TODO: Implement the successful workflow.

# %% [markdown]
# ## 4. Change an input
#
# TODO: Add a tampering or failure experiment and an observation prompt.

# %%
# TODO: Implement the controlled failure experiment.

# %% [markdown]
# ## 5. Your implementation
#
# TODO: Define the learner task, hints, and expected behavior.

# %%
# TODO: Learner implementation.

# %% [markdown]
# ## 6. Checks
#
# TODO: Add meaningful assertions for successful and rejected inputs. Placeholder cells do not count as passing a lab.

# %%
# TODO: Add acceptance checks after the exercise is implemented.

# %% [markdown]
# ## 7. Reflection and cleanup
#
# - What property did the mechanism provide?
# - What did it leave unprotected?
# - What would change in a deployed system?
#
# TODO: Add lab-specific cleanup and optional extensions.
